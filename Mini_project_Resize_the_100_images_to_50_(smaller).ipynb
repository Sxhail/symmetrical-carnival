# %% [markdown]
# <a href="https://colab.research.google.com/github/Sxhail/symmetrical-carnival/blob/main/Mini_project_Resize_the_100_images_to_50_(smaller).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google_images_search > /dev/null
# !pip install opencv-python > /dev/null

# %%
from google_images_search import GoogleImagesSearch
import zipfile
import os
# you can provide API key and CX using arguments,
# or you can set environment variables: GCS_DEVELOPER_KEY, GCS_CX
gis = GoogleImagesSearch('AIzaSyDbmFd1bRQcxXB2gPJi5_aN_DUCFfJlJoU' , '37e600c7708934c15' , validate_images=True)
def search(keyword, imageNumber):
    _search_params = {
        'q': keyword,
        'num': imageNumber,
        # 'safe': 'medium',
         #'fileType': 'jpg',
         #'imgType': 'photo',
        # 'imgSize': 'MEDIUM',
         'imgDominantColor': 'blue',
        # 'rights': 'cc_publicdomain'
    }

    #path_to_dir: where the downloaded images must be stored
    gis.search(search_params=_search_params, path_to_dir= './images/')

search('books',100)

# %%
from google.colab.patches import cv2_imshow
import cv2
for image_name in os.listdir('/content/images'):

    # Construct the full path to the image file
    img_path = os.path.join('/content/images', image_name)

    # Read the image using OpenCV
    img = cv2.imread(img_path, -1)
    img = cv2.resize(img, None, fx=0.5, fy=0.5)

    # Display the image using cv2_imshow
    if img is not None:
        # Display the image using cv2_imshow
        cv2_imshow(img)
    else:
        print(f"Failed to read image: {img_path}")
# Out:
# <PIL.Image.Image image mode=RGBA size=285x214>
# <PIL.Image.Image image mode=RGBA size=320x246>
# <PIL.Image.Image image mode=RGBA size=488x274>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     517     try:
# --> 518         fh = fp.fileno()
#     519         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0d4d82eeff8c> in <cell line: 3>()
#      13     if img is not None:
#      14         # Display the image using cv2_imshow
# ---> 15         cv2_imshow(img)
#      16     else:
#      17         print(f"Failed to read image: {img_path}")
#
# ...
